# %%
import pickle
import os
import yaml
import pandas as pd
import numpy as np
import matplotlib
# matplotlib.style.use("ggplot")
import matplotlib.pyplot as plt
from SALib.analyze import fast
import sqlite3

# %%
with open(os.path.join('yaml', 'params2.yaml'), 'r', encoding='utf-8') as f:
    problem_yaml = f.read()
problem = yaml.safe_load(problem_yaml)

# %%
with open("../fastsample1.sam", "r", encoding="utf-8") as f:
    problem_name = list()
    tmp_list, res_list = list(), list()
    count = 0
    f.seek(0)
    flag = 0
    for num, line in enumerate(f):
        if num == 1:
            total = int(line)
            continue
        elif num == 2:
            num_var = int(line)
            continue

        elif num > 2:

            try:
                line = line.rstrip()
                tmp_list = line.split('\t')
                # print(len(tmp_list))
                if len(tmp_list) == num_var and count < total:
                    res_list.append(tmp_list)
                    count += 1
                else:
                    temp_str = f"{num_var} Distributions"
                    if temp_str in line:
                        start1 = num + 2
                        flag = 1
                        count1 = 0
                    
                    if flag and count1 < num_var and num == start1 + count1*6:
                        problem_name.append(line)
                        count1 += 1

            except ValueError:
                pass


paramsets = np.array(res_list, dtype=np.float64)

# %%
problem_dict1 = dict()
for each in problem_name:
    for name, value in zip(problem["names"], problem["bounds"]):
        if each == name:
            problem_dict1[each] = value

# %%
bounds_list = list()

# %%
for each in problem_name:
    bounds_list.append(problem_dict1[each])

# %%
problem["bounds"] = bounds_list
problem["names"] = problem_name
problem["num_vars"] = len(bounds_list)

# %%
def gen_res_dict(input_dict: dict):
    tmp_df = None
    for key_ in input_dict.keys():
        
        if key_.isnumeric():
            if key_ == "0":
                name = input_dict["names1"]
                tmp_df = pd.DataFrame(input_dict[key_], columns=input_dict["names1"])
            else:
                name = input_dict["names2"]
                tmp_df = pd.DataFrame(input_dict[key_], columns=input_dict["names2"])
            
            yield (key_, name, tmp_df)

# %%
def create_sql(path_sql):
    conn = sqlite3.connect(path_sql)
    c = conn.cursor()
    for var_name in col2[: -1]:
        for ni in n_amout:
            table_name1 = "PPN%s%s" % (ni, var_name)
            # table_name2 = "PPN%s2022%s" % (ni, var_name)
            c.execute(f"""CREATE TABLE {table_name1}
            (ID INTEGER PRIMARY KEY AUTOINCREMENT,
            YEAR INT NOT NULL,
            Parameter CHAR(20) NOT NULL,
            First_order REAL,
            Total_order REAL,
            DOY INT NOT NULL);""")
            conn.commit()
    conn.close()

# %%
root_dir = "./pickleFile/FinalRes/"
for dir_root, _, file_list in os.walk(root_dir):
    for file_name in file_list:
        save_name = file_name.split(".")[0]
        with open(os.path.join(dir_root, file_name), 'rb') as f:
            result_pp = pickle.load(f)
        
        gen_dict = gen_res_dict(result_pp)
        for num_, names_l, df1 in gen_dict:
            if num_ == "0":
                continue
            else:
                
                save_dir = save_dir2
            for each in names_l[: -1]:
                Y = df1[each]
                Y = Y.to_numpy()
                Si = fast.analyze(problem, Y, print_to_console=False)
                df_sensitivity = pd.DataFrame({
                    "Parameter": problem["names"],
                    "First_order": Si["S1"],
                    "Total_order": Si["ST"]}).set_index("Parameter")
                df_sensitivity["YEAR"] = 2021
                df_sensitivity["DOY"] = int(num_)
                save_name1 = f"PPN0LAI"
                df_sensitivity.to_sql(save_name1, con=conn, chunksize=10000, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_42168\178491753.py in <module>
#      19                 Y = df1[each]
#      20                 Y = Y.to_numpy()
# ---> 21                 Si = fast.analyze(problem, Y, print_to_console=False)
#      22                 df_sensitivity = pd.DataFrame({
#      23                     "Parameter": problem["names"],
#
# D:\anaconda3\lib\site-packages\SALib\analyze\fast.py in analyze(problem, Y, M, num_resamples, conf_level, print_to_console, seed)
#      96         Si["ST"][i] = ST
#      97
# ---> 98         S1_d_conf, ST_d_conf = bootstrap(Y_l, M, num_resamples, conf_level)
#      99         Si["S1_conf"][i] = S1_d_conf
#     100         Si["ST_conf"][i] = ST_d_conf
#
# D:\anaconda3\lib\site-packages\SALib\analyze\fast.py in bootstrap(Y, M, resamples, conf_level)
#     138         omega = math.floor((N - 1) / (2 * M))
#     139
# --> 140         S1, ST = compute_orders(Y_rs, N, M, omega)
#     141         res_S1[i] = S1
#     142         res_ST[i] = ST
#
# D:\anaconda3\lib\site-packages\SALib\analyze\fast.py in compute_orders(outputs, N, M, omega)
#     107
#     108 def compute_orders(outputs: np.ndarray, N: int, M: int, omega: int):
# --> 109     f = np.fft.fft(outputs)
#     110     Sp = np.power(np.absolute(f[np.arange(1, math.ceil(N / 2))]) / N, 2)
#     111
#
# <__array_function__ internals> in fft(*args, **kwargs)
#
# D:\anaconda3\lib\site-packages\numpy\fft\_pocketfft.py in fft(a, n, axis, norm)
#     213         n = a.shape[axis]
#     214     inv_norm = _get_forward_norm(n, norm)
# --> 215     output = _raw_fft(a, n, axis, False, True, inv_norm)
#     216     return output
#     217
#
# D:\anaconda3\lib\site-packages\numpy\fft\_pocketfft.py in _raw_fft(a, n, axis, is_real, is_forward, inv_norm)
#      68
#      69     if axis == a.ndim-1:
# ---> 70         r = pfi.execute(a, is_real, is_forward, fct)
#      71     else:
#      72         a = swapaxes(a, axis, -1)
#
# KeyboardInterrupt:

# %%
# Out:
#     Parameter  First_order  Total_order  YEAR  DOY
# 0      SLATB1          NaN          NaN  2021   10
# 1      SLATB2          NaN          NaN  2021   10
# 2      SLATB3          NaN          NaN  2021   10
# 3     KDIFTB0          NaN          NaN  2021   10
# 4     KDIFTB2          NaN          NaN  2021   10
# 5      EFFTB1          NaN          NaN  2021   10
# 6      EFFTB2          NaN          NaN  2021   10
# 7   AMAXTB125          NaN          NaN  2021   10
# 8   AMAXTB150          NaN          NaN  2021   10
# 9   AMAXTB175          NaN          NaN  2021   10
# 10  AMAXTB000          NaN          NaN  2021   10
# 11  AMAXTB200          NaN          NaN  2021   10
# 12    TMPFTB0          NaN          NaN  2021   10
# 13   TMPFTB30          NaN          NaN  2021   10
# 14    TMNFTB8          NaN          NaN  2021   10
# 15    RFSETB0          NaN          NaN  2021   10
# 16    RFSETB2          NaN          NaN  2021   10
# 17        CVL          NaN          NaN  2021   10
# 18        CVO          NaN          NaN  2021   10
# 19        CVR          NaN          NaN  2021   10
# 20        CVS          NaN          NaN  2021   10
# 21        Q10          NaN          NaN  2021   10
# 22        RML          NaN          NaN  2021   10
# 23        RMO          NaN          NaN  2021   10
# 24        RMR          NaN          NaN  2021   10
# 25        RMS          NaN          NaN  2021   10
# 26      PERDL          NaN          NaN  2021   10
# 27        RDI          NaN          NaN  2021   10
# 28        RRI          NaN          NaN  2021   10
# 29     TBASEM          NaN          NaN  2021   10
# 30     TEFFMX          NaN          NaN  2021   10
# 31      TSUM1          NaN          NaN  2021   10
# 32      TSUM2          NaN          NaN  2021   10
# 33       TDWI          NaN          NaN  2021   10
# 34     RGRLAI          NaN          NaN  2021   10
# 35       SPAN          NaN          NaN  2021   10

# %%
def df_mean(df1, df2):
    return (df1 + df2) / 2.0

# %%
n_amout = [0, 90, 180, 270]
root_dir = "./modelOut/Si/"

# %%
col1 = ["LAIMAX", "TAGP", "TWSO", "id"]
col2 = ["LAI", "TAGP", "id"]
for var_name in col1[: -1]:
    for ni in n_amout:
        file_name1 = f"WLPN{ni}2021_{var_name}_0.csv"
        file_name2 = f"WLPN{ni}2022_{var_name}_0.csv"
        df1 = pd.read_csv(os.path.join(root_dir, file_name1), header=0, index_col=0)
        df2 = pd.read_csv(os.path.join(root_dir, file_name2), header=0, index_col=0)
        df = df_mean(df1, df2)
        df.to_csv(os.path.join(root_dir, f"WLPN{ni}_{var_name}.csv"))

# %%
conn.close()

# %%
conn = sqlite3.connect('time_series.db')

# %%
c = conn.cursor()

# %%
conn = sqlite3.connect('time_series.db')
c = conn.cursor()
for var_name in col2[: -1]:
    for ni in n_amout:
        table_name1 = "PPN%s%s" % (ni, var_name)
        # table_name2 = "PPN%s2022%s" % (ni, var_name)
        c.execute(f"""CREATE TABLE {table_name1}
        (ID INTEGER PRIMARY KEY AUTOINCREMENT,
        YEAR INT NOT NULL,
        Parameter CHAR(20) NOT NULL,
        First_order REAL,
        Total_order REAL,
        DOY INT NOT NULL);""")
        conn.commit()
conn.close()

# %%
df1["id"] = 1

# %%
df1
# Out:
#            First_order  Total_order  id
# Parameter
# SLATB1        0.096058     0.191488   1
# SLATB2        0.008117     0.016103   1
# SLATB3        0.000034     0.003235   1
# KDIFTB0       0.035883     0.056186   1
# KDIFTB2       0.000685     0.013220   1
# EFFTB1        0.008553     0.015379   1
# EFFTB2        0.091203     0.158128   1
# AMAXTB125     0.007670     0.015771   1
# AMAXTB150     0.000612     0.001724   1
# AMAXTB175     0.001911     0.009608   1
# AMAXTB000     0.004137     0.014710   1
# AMAXTB200     0.000203     0.002531   1
# TMPFTB0       0.000013     0.001700   1
# TMPFTB30      0.033982     0.076631   1
# TMNFTB8       0.490636     0.641260   1
# RFSETB0       0.000277     0.002166   1
# RFSETB2       0.000200     0.004458   1
# CVL           0.056917     0.092623   1
# CVO           0.089000     0.145596   1
# CVR           0.002566     0.006694   1
# CVS           0.017882     0.044565   1
# Q10           0.008072     0.023104   1
# RML           0.004219     0.007950   1
# RMO           0.002609     0.008397   1
# RMR           0.001144     0.006845   1
# RMS           0.011887     0.025663   1
# PERDL         0.000031     0.001534   1
# RDI           0.000032     0.001294   1
# RRI           0.000102     0.005262   1
# TBASEM        0.000472     0.003121   1
# TEFFMX        0.000025     0.001125   1
# TSUM1         0.123743     0.199077   1
# TSUM2         0.052372     0.102341   1
# TDWI          0.001511     0.004633   1
# RGRLAI        0.000095     0.013940   1
# SPAN          0.091731     0.218443   1
